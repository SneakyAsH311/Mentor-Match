# %% [markdown]
# <a href="https://colab.research.google.com/github/SneakyAsH311/Mentor-Match/blob/master/MentorMatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mentor Match:
# Using a data-driven approach to match mentors to students with similiar interests will improve the mentorship program!

# %% [markdown]
# # Introduction:
# Mentoring is a crucial component of the P-TECH 9-14 model. Through mentoring, industry professionals are invited into the school
# community. They offer students with meaningful academic, workplace learning and social/emotional support. Likewise, mentoring gives
# students with an adult role model and a guide who works in the field they are studying. Mentors can also provide emotional support,
# encouragement, and meaningful feedback on coursework.
#
# ## Problem:
# While mentors have an important role in the p-tech model, the way mentors are chosen for students has quite a few problems. Mentors are matched almost completely randomly and are matched manually by the program manager. This is not only very time consuming for the program manager, but it isn't a scalable solution for the inevitable expansion of P-TECH. Through my experience, and my conversations with both Students and Mentors, I have found that the mentors assigned to students often have little in common with the students. Through my research, I have found that this causes unfulfilling mentor-student relationships and reduce overall engagement from both parties.
#
# ### Problem(Summarized):
# The method of matching mentors at P-TECH is unscalable and can be improved. Poorly matched mentors are  having a negative effect in the mentor-mentee relationships.
#
# ##Solution:
#
# Using a data-driven approach to match mentors to students with similiar interests will improve the quality of the mentorship program! Giving students mentors who have similiar interests is much more intuitive for a relationship that has major focus on guidance. Also an algorithmic approach to this save program manager valueable time!
#
# The steps to a better mentor matching framework are outlined below:
#
#
#
# 1.   Survey
# 2.   Matching algorithm
# 3.   Happy mentor and students :)

# %%
# %pip install names
import pandas as pd
import numpy as np
import names
# Out:
# Collecting names
#   Downloading https://files.pythonhosted.org/packages/44/4e/f9cb7ef2df0250f4ba3334fbdabaa94f9c88097089763d8e85ada8092f84/names-0.3.0.tar.gz (789kB)
#     100% |████████████████████████████████| 798kB 22.9MB/s
# Building wheels for collected packages: names
#   Building wheel for names (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/f9/a5/e1/be3e0aaa6fa285575078fa2aafd9959b45bdbc8de8a6803aeb
# Successfully built names
# Installing collected packages: names
# Successfully installed names-0.3.0

# %% [markdown]
# # Step 1: Survey
#
# *This is probably the most important step*
#
# We need to ask every person(Students and Mentors) the right questions regarding what we want to get out of the mentor-mentee relationship. If it is career advice career focused questions might be the best andif it is school advice subject-focused questions might be best!
#
#
#
# Create student and mentor datasets in the form of:
# {Name : [rating1, rating2, rating3, rating4, rating5, ... ratingN]} for N categories
#
# ## Example survey questions:
# ### Enter name: Abdullah Saleh
# ### How interested are you in the following topics in a scale from 1-5; 1 being least interested, 5 being the most:
#
# 1. Computer Science: 5
#
# 2. Buisness: 5
#
# 3. History: 1
#
# 4. Design: 3
#
# 5. Biology: 3
#
# 6. Physics: 5
#
# 7. Chemistry: 4
#
#
#
#
#
#
#
#
#
# ---
#
# ## output: {Abdullah Saleh: [5,5,1,3,3,5,4]}

# %% [markdown]
# ---
#
# # Mock Data:
# random names - random scores
#
# In this example we will create mock data for 300 mentors and 300 students!

# %%
# Create an array of size 300 for mentors and 600 for students with a random int value between 1 and 5
mentor = np.random.randint(1,6,size=[300,5])
student = np.random.randint(1,6,size=[600,5])

def create_dataset(data):
    dataset = {}
    for i in data:
        dataset[names.get_full_name()] = i
    return dataset
mentor_dataset = create_dataset(mentor)
student_dataset = create_dataset(student)
mentor_dataset
# Out:
# {'Aaron Gomes': array([2, 3, 3, 5, 2]),
#  'Aaron Saunders': array([5, 4, 3, 1, 3]),
#  'Adam Butler': array([2, 2, 2, 2, 4]),
#  'Aileen Newman': array([1, 1, 2, 2, 1]),
#  'Alice Gates': array([4, 5, 3, 2, 3]),
#  'Alice Tanner': array([2, 1, 1, 2, 2]),
#  'Alvin Buford': array([5, 2, 3, 5, 5]),
#  'Alvin Carlyle': array([2, 2, 2, 4, 2]),
#  'Alvina Plues': array([4, 2, 1, 5, 4]),
#  'Amy Williams': array([4, 1, 1, 2, 5]),
#  'Andrew Cooper': array([3, 1, 4, 1, 5]),
#  'Ann Martinez': array([2, 3, 1, 3, 1]),
#  'Ann Rosenthal': array([5, 3, 1, 4, 2]),
#  'Anna Baker': array([3, 1, 4, 4, 1]),
#  'Antonio Macias': array([4, 4, 5, 4, 1]),
#  'Arthur Clark': array([3, 1, 3, 4, 2]),
#  'Ashley Abernethy': array([3, 2, 5, 4, 3]),
#  'Ashley Martone': array([5, 3, 4, 3, 5]),
#  'August Littlefield': array([1, 4, 2, 3, 4]),
#  'Barbara Green': array([3, 4, 4, 4, 3]),
#  'Benjamin Bryce': array([3, 2, 5, 1, 3]),
#  'Berry Romero': array([1, 3, 5, 1, 2]),
#  'Bessie Bradshaw': array([3, 5, 2, 2, 4]),
#  'Bethany Guedjian': array([3, 4, 4, 1, 1]),
#  'Bette Edwards': array([4, 2, 5, 2, 3]),
#  'Betty Bevis': array([2, 1, 2, 5, 3]),
#  'Bobby Lewis': array([3, 4, 3, 1, 2]),
#  'Bonnie Shute': array([3, 2, 3, 4, 1]),
#  'Brad Minor': array([2, 5, 2, 1, 2]),
#  'Bradford Thibeault': array([4, 4, 2, 2, 4]),
#  'Brandon Colley': array([4, 1, 4, 5, 2]),
#  'Brandon Flower': array([5, 5, 5, 1, 5]),
#  'Brian Kocur': array([1, 3, 2, 5, 2]),
#  'Bruce Davis': array([1, 4, 2, 4, 3]),
#  'Bryan Maestas': array([4, 1, 2, 3, 5]),
#  'Buddy Hardin': array([2, 2, 5, 4, 1]),
#  'Carla Britt': array([1, 4, 2, 5, 2]),
#  'Carlos Stroud': array([3, 5, 2, 5, 1]),
#  'Caroline Hodges': array([5, 4, 4, 2, 5]),
#  'Carolyn Kersey': array([3, 3, 3, 4, 3]),
#  'Casey Scerra': array([2, 2, 2, 3, 3]),
#  'Catherine Lowe': array([2, 1, 4, 5, 5]),
#  'Charles Fanelli': array([5, 1, 1, 4, 1]),
#  'Cherri Trombley': array([2, 1, 3, 5, 3]),
#  'Cheryl Selmer': array([4, 4, 5, 3, 4]),
#  'Chester Vanconant': array([2, 4, 3, 5, 5]),
#  'Christine Faust': array([3, 4, 1, 5, 3]),
#  'Christoper Crawford': array([3, 3, 1, 2, 4]),
#  'Christopher Harley': array([5, 2, 5, 4, 1]),
#  'Christopher Murray': array([3, 5, 5, 3, 2]),
#  'Christopher Robinson': array([5, 3, 1, 5, 2]),
#  'Clarence Fried': array([1, 1, 5, 3, 4]),
#  'Cliff Hernandez': array([1, 5, 5, 2, 3]),
#  'Connie Garrett': array([5, 1, 1, 2, 1]),
#  'Connie Watson': array([4, 2, 2, 2, 3]),
#  'Courtney Schneider': array([1, 3, 3, 2, 4]),
#  'Daisy Peterson': array([4, 2, 1, 3, 3]),
#  'Daniel Garlington': array([3, 1, 1, 3, 5]),
#  'Daniel Lynch': array([3, 1, 3, 4, 5]),
#  'Daniel Marable': array([3, 4, 2, 5, 5]),
#  'Darlene Johnson': array([2, 2, 4, 1, 1]),
#  'Darren Wall': array([2, 3, 3, 1, 4]),
#  'Darwin Chun': array([1, 4, 2, 3, 4]),
#  'Daryl Darden': array([5, 3, 4, 2, 4]),
#  'David Martinez': array([1, 4, 2, 5, 2]),
#  'David Smith': array([1, 1, 2, 1, 4]),
#  'David Womack': array([5, 5, 5, 4, 4]),
#  'David Wynn': array([2, 3, 1, 2, 1]),
#  'Dean Evans': array([5, 5, 3, 2, 5]),
#  'Dean Javier': array([5, 5, 3, 4, 4]),
#  'Dean Peel': array([4, 2, 5, 1, 1]),
#  'Deborah Elliott': array([1, 2, 5, 3, 3]),
#  'Deborah Evans': array([1, 2, 2, 3, 5]),
#  'Delia Myers': array([4, 4, 1, 1, 4]),
#  'Delia Turner': array([3, 2, 5, 3, 4]),
#  'Dennis Davis': array([1, 5, 4, 3, 2]),
#  'Derek Karp': array([4, 1, 4, 3, 2]),
#  'Diane Mccants': array([3, 5, 1, 4, 1]),
#  'Donald Bell': array([1, 4, 5, 3, 2]),
#  'Donald Mcdonald': array([2, 3, 5, 2, 5]),
#  'Donald Shaddox': array([5, 1, 2, 3, 3]),
#  'Donald Wade': array([2, 2, 2, 3, 5]),
#  'Dustin Ortiz': array([5, 3, 3, 3, 1]),
#  'Edward Chappell': array([1, 4, 1, 1, 2]),
#  'Edward Clayton': array([1, 2, 4, 2, 1]),
#  'Edward Cramer': array([3, 4, 2, 5, 4]),
#  'Edward Robinson': array([1, 3, 1, 3, 4]),
#  'Eileen Cohen': array([3, 4, 1, 4, 1]),
#  'Eleanor Perryman': array([3, 4, 4, 1, 3]),
#  'Elizabeth Carter': array([2, 2, 1, 3, 5]),
#  'Elizabeth Wertheim': array([3, 1, 2, 1, 4]),
#  'Elton Watkins': array([3, 1, 4, 1, 2]),
#  'Emily Miles': array([1, 3, 3, 4, 1]),
#  'Eric Hutchison': array([3, 4, 2, 3, 1]),
#  'Eric Narvaez': array([4, 3, 4, 4, 2]),
#  'Eric Sparks': array([5, 3, 3, 1, 4]),
#  'Ernest States': array([4, 4, 4, 2, 3]),
#  'Ethel Wagner': array([4, 4, 1, 1, 4]),
#  'Evelyn Mcmahan': array([4, 1, 2, 4, 3]),
#  'Flor Glowacky': array([4, 3, 1, 5, 4]),
#  'Forrest Hosie': array([3, 5, 5, 1, 3]),
#  'Frances Jensen': array([4, 4, 2, 1, 4]),
#  'Francis Goodin': array([3, 4, 3, 1, 4]),
#  'Frank Bratt': array([1, 1, 1, 2, 5]),
#  'Frank Hill': array([5, 1, 5, 5, 2]),
#  'Freda Johnson': array([1, 2, 2, 1, 2]),
#  'George Davis': array([1, 3, 3, 5, 4]),
#  'George Krug': array([1, 2, 5, 2, 5]),
#  'George White': array([5, 1, 4, 1, 3]),
#  'Georgia Ridge': array([2, 1, 2, 4, 2]),
#  'Glen Whiteside': array([5, 2, 4, 5, 4]),
#  'Greg Erdmann': array([5, 3, 1, 2, 1]),
#  'Harold Green': array([5, 2, 4, 5, 5]),
#  'Harry Roland': array([3, 2, 1, 1, 1]),
#  'Hazel Shirk': array([4, 1, 5, 1, 3]),
#  'Helen Faulkner': array([1, 5, 4, 2, 2]),
#  'Helen Leandry': array([3, 4, 2, 3, 5]),
#  'Helen Steller': array([2, 3, 2, 2, 3]),
#  'Henry Brewer': array([3, 2, 1, 4, 1]),
#  'Hermelinda Daughters': array([2, 2, 2, 2, 1]),
#  'Isidra Martin': array([2, 1, 3, 1, 3]),
#  'Jack Kuker': array([4, 1, 3, 4, 5]),
#  'Jackie Clairmont': array([4, 5, 1, 2, 1]),
#  'Jamel Burnette': array([5, 2, 3, 3, 3]),
#  'James Davis': array([5, 3, 1, 3, 5]),
#  'James Edwards': array([4, 1, 3, 5, 3]),
#  'James Parker': array([1, 5, 2, 1, 4]),
#  'James Pischke': array([3, 4, 4, 2, 5]),
#  'James Sampson': array([3, 4, 2, 1, 4]),
#  'Jamie Yazzie': array([1, 1, 3, 4, 4]),
#  'Jamila Sutton': array([5, 4, 2, 1, 5]),
#  'Janet Chaney': array([5, 3, 5, 2, 5]),
#  'Janet Roberson': array([3, 4, 2, 1, 2]),
#  'Jared Ortiz': array([3, 1, 3, 2, 4]),
#  'Jason Ford': array([2, 1, 3, 5, 1]),
#  'Jason Jackson': array([5, 2, 1, 3, 4]),
#  'Jean Dirks': array([5, 4, 3, 2, 4]),
#  'Jeffery Spangler': array([1, 3, 5, 3, 2]),
#  'Jesse Kierzewski': array([5, 2, 2, 1, 5]),
#  'Jewell Mack': array([3, 2, 5, 1, 2]),
#  'Jill Stromberg': array([3, 4, 3, 4, 3]),
#  'Jimmy Gardner': array([1, 3, 1, 1, 5]),
#  'John Blais': array([5, 1, 1, 1, 5]),
#  'John Brandt': array([5, 3, 3, 1, 5]),
#  'John Cumberledge': array([2, 2, 5, 1, 3]),
#  'John Edwards': array([3, 5, 3, 4, 1]),
#  'John Garrett': array([3, 2, 4, 3, 5]),
#  'John Guillette': array([3, 4, 3, 2, 1]),
#  'John Hernandez': array([5, 2, 1, 3, 4]),
#  'John Kenkel': array([5, 3, 4, 1, 3]),
#  'John Lundy': array([2, 1, 2, 1, 5]),
#  'John Paul': array([5, 3, 1, 2, 4]),
#  'John Riddick': array([4, 4, 1, 4, 2]),
#  'Johnny Leonard': array([2, 5, 2, 4, 3]),
#  'Jolene Herrara': array([2, 2, 4, 3, 3]),
#  'Jonathan Tebow': array([3, 2, 5, 2, 4]),
#  'Joseph Horn': array([2, 3, 3, 2, 3]),
#  'Joseph Teneyck': array([4, 1, 5, 2, 3]),
#  'Joseph Wilenkin': array([2, 3, 1, 5, 5]),
#  'Joshua Cauthen': array([3, 4, 5, 5, 4]),
#  'Joyce Ferguson': array([3, 1, 5, 5, 3]),
#  'Juan Gusler': array([4, 1, 3, 5, 1]),
#  'Julianna Barge': array([5, 2, 2, 1, 3]),
#  'Julie Gabel': array([5, 5, 4, 3, 1]),
#  'Julie Jensen': array([3, 1, 3, 3, 3]),
#  'Julie Sage': array([4, 2, 4, 2, 2]),
#  'Kaitlin Alexander': array([4, 1, 1, 4, 1]),
#  'Karen Boehm': array([4, 4, 1, 2, 1]),
#  'Karen Valado': array([3, 3, 1, 3, 3]),
#  'Karen Whitted': array([4, 4, 2, 2, 5]),
#  'Keith Henricks': array([4, 2, 4, 5, 2]),
#  'Kelly Holmes': array([1, 5, 5, 3, 5]),
#  'Kenneth Bumpus': array([1, 2, 4, 1, 3]),
#  'Kenneth Tiller': array([5, 3, 1, 5, 3]),
#  'Keven Jones': array([1, 5, 4, 5, 4]),
#  'Kevin Johnson': array([4, 4, 4, 4, 4]),
#  'Kevin Sipes': array([3, 2, 4, 1, 5]),
#  'Kristen Riley': array([5, 1, 3, 1, 3]),
#  'Kristy Weafer': array([1, 5, 2, 4, 4]),
#  'Kurt Hansel': array([3, 3, 1, 3, 4]),
#  'Kurt Smith': array([1, 3, 4, 5, 4]),
#  'Lady Madsen': array([4, 4, 2, 3, 4]),
#  'Lakesha Reynolds': array([3, 3, 2, 4, 1]),
#  'Larry Lacroix': array([3, 5, 1, 2, 3]),
#  'Laura Younger': array([2, 5, 2, 2, 3]),
#  'Lawrence Bennett': array([3, 3, 3, 5, 5]),
#  'Lee Martins': array([3, 5, 5, 2, 5]),
#  'Lee Trimble': array([1, 1, 3, 3, 4]),
#  'Lee Wren': array([5, 5, 3, 2, 4]),
#  'Leonard Sawyer': array([4, 3, 3, 3, 2]),
#  'Lewis Smolka': array([3, 2, 1, 2, 2]),
#  'Lillie Francois': array([2, 3, 2, 2, 5]),
#  'Linda Larish': array([1, 4, 1, 1, 5]),
#  'Lisa Florentino': array([3, 4, 1, 5, 1]),
#  'Lisa Phillips': array([1, 5, 2, 2, 4]),
#  'Lisa Tompkins': array([3, 5, 5, 1, 2]),
#  'Lolita Ruiz': array([4, 2, 2, 5, 1]),
#  'Louie Niebaum': array([5, 2, 4, 3, 3]),
#  'Luis Nichols': array([5, 4, 4, 3, 5]),
#  'Lyle Reardon': array([3, 3, 5, 1, 3]),
#  'Lynn Lewis': array([4, 1, 2, 2, 4]),
#  'Mack Carter': array([2, 4, 1, 4, 4]),
#  'Malcolm Oneill': array([4, 5, 4, 4, 1]),
#  'Manuel Little': array([3, 2, 1, 2, 1]),
#  'Maria Overbaugh': array([4, 3, 2, 2, 3]),
#  'Martin Livingston': array([4, 1, 5, 5, 5]),
#  'Mary Cormier': array([2, 3, 5, 4, 2]),
#  'Mary Phoenix': array([2, 1, 4, 1, 4]),
#  'Mathew Visitacion': array([1, 1, 4, 1, 2]),
#  'Matthew Morse': array([1, 1, 3, 2, 1]),
#  'Matthew Presler': array([1, 4, 1, 1, 3]),
#  'Michael Hill': array([3, 1, 1, 3, 5]),
#  'Michael Romano': array([5, 1, 4, 3, 5]),
#  'Migdalia Feinberg': array([3, 4, 2, 2, 1]),
#  'Nannie Mori': array([2, 1, 4, 1, 4]),
#  'Nannie Rigby': array([4, 5, 4, 1, 5]),
#  'Nathan Yates': array([4, 5, 5, 2, 3]),
#  'Neva Milburn': array([3, 3, 3, 1, 3]),
#  'Nicky Mercier': array([5, 2, 3, 2, 2]),
#  'Nicolas Tate': array([1, 5, 4, 4, 3]),
#  'Nicole Hamill': array([4, 1, 1, 1, 5]),
#  'Nikki Williams': array([2, 5, 2, 3, 2]),
#  'Noelle Castro': array([3, 1, 5, 2, 1]),
#  'Norman Mittman': array([5, 3, 1, 3, 4]),
#  'Olivia Champagne': array([3, 5, 2, 1, 2]),
#  'Pamela Langer': array([5, 5, 3, 4, 1]),
#  'Pamela Simpson': array([2, 1, 5, 3, 5]),
#  'Patricia Arreola': array([4, 4, 4, 5, 4]),
#  'Paul Lankford': array([3, 4, 2, 5, 1]),
#  'Paula Rice': array([5, 4, 3, 1, 4]),
#  'Paulette Lamb': array([5, 3, 2, 5, 1]),
#  'Pauline Waller': array([3, 1, 3, 2, 5]),
#  'Peggy Young': array([1, 4, 1, 5, 4]),
#  'Peter Balsamo': array([1, 1, 5, 4, 4]),
#  'Peter Ghan': array([2, 2, 3, 1, 1]),
#  'Peter Mefford': array([2, 4, 2, 4, 2]),
#  'Philip Hurlburt': array([3, 1, 4, 4, 2]),
#  'Ramona Sims': array([4, 3, 4, 4, 3]),
#  'Ray Johnston': array([2, 4, 3, 1, 4]),
#  'Raymond Hruska': array([1, 4, 1, 5, 1]),
#  'Raymond Jacques': array([3, 2, 3, 4, 5]),
#  'Reba Best': array([5, 4, 4, 4, 1]),
#  'Rebecca Pruiett': array([5, 2, 2, 1, 5]),
#  'Reggie Bartlett': array([1, 4, 2, 4, 1]),
#  'Reginald Spindler': array([5, 5, 4, 2, 3]),
#  'Robert Bryan': array([2, 2, 1, 2, 2]),
#  'Robert Butler': array([3, 2, 2, 4, 4]),
#  'Robert Lorenzen': array([4, 2, 4, 4, 5]),
#  'Roger Byrd': array([5, 3, 1, 3, 5]),
#  'Roger Goodman': array([5, 1, 4, 5, 3]),
#  'Roland Baker': array([3, 5, 1, 1, 2]),
#  'Ronnie Lawton': array([2, 2, 2, 2, 4]),
#  'Roosevelt Elkins': array([3, 2, 3, 2, 4]),
#  'Roosevelt Frey': array([1, 2, 5, 4, 5]),
#  'Rosa Zerger': array([5, 4, 1, 1, 3]),
#  'Russell Jones': array([1, 5, 1, 5, 2]),
#  'Ruth Page': array([2, 3, 5, 2, 1]),
#  'Ryan Harris': array([3, 4, 2, 3, 2]),
#  'Samantha Hamel': array([1, 3, 5, 5, 2]),
#  'Samantha Janak': array([4, 5, 4, 4, 4]),
#  'Samuel Cook': array([2, 5, 5, 3, 5]),
#  'Samuel Schmidt': array([4, 3, 4, 2, 5]),
#  'Sandra Morring': array([1, 2, 4, 3, 2]),
#  'Sandy Handly': array([3, 3, 2, 1, 2]),
#  'Sarah Shafer': array([2, 1, 4, 4, 4]),
#  'Sarah Wilson': array([2, 3, 4, 3, 4]),
#  'Scott Vanschaick': array([1, 3, 2, 5, 2]),
#  'Serena Gross': array([5, 1, 4, 1, 1]),
#  'Shanna Cansler': array([2, 2, 2, 1, 3]),
#  'Shannon Troendle': array([4, 2, 1, 1, 3]),
#  'Sheri Oswald': array([2, 4, 3, 5, 5]),
#  'Shiela Frank': array([4, 1, 1, 5, 5]),
#  'Shirley Holcomb': array([1, 3, 2, 2, 2]),
#  'Stanley Stanton': array([5, 3, 1, 1, 1]),
#  'Stephen Gould': array([4, 3, 1, 2, 3]),
#  'Stephen Perez': array([1, 5, 4, 3, 4]),
#  'Stephen Valdes': array([2, 5, 4, 2, 2]),
#  'Steve Northover': array([1, 5, 1, 5, 2]),
#  'Steven Arroyo': array([5, 3, 2, 2, 2]),
#  'Susan Francis': array([2, 3, 1, 1, 1]),
#  'Susan Weske': array([2, 5, 5, 1, 4]),
#  'Teresa Bean': array([5, 3, 2, 3, 1]),
#  'Terry Cornelius': array([4, 1, 3, 5, 2]),
#  'Thelma Nemeth': array([3, 4, 1, 2, 5]),
#  'Theodore Crawford': array([5, 5, 1, 5, 4]),
#  'Thomas Berry': array([3, 4, 4, 5, 5]),
#  'Thomas Cobbs': array([3, 2, 4, 4, 3]),
#  'Thomas Leake': array([1, 5, 1, 4, 3]),
#  'Tina Merritt': array([3, 2, 1, 5, 2]),
#  'Tommy Harner': array([4, 1, 1, 1, 4]),
#  'Tony Watkins': array([4, 2, 2, 3, 5]),
#  'Trisha Salazar': array([4, 5, 1, 5, 4]),
#  'Vanessa Holmes': array([5, 3, 5, 4, 2]),
#  'Wayne Turbacuski': array([3, 1, 4, 5, 4]),
#  'William Hsu': array([1, 3, 5, 4, 2]),
#  'William Metz': array([2, 2, 1, 2, 4]),
#  'William Sands': array([5, 1, 2, 5, 2]),
#  'Willie Hollingsworth': array([4, 4, 3, 1, 3]),
#  'Wilton Lewis': array([1, 4, 3, 2, 2])}

# %% [markdown]
# # Step 2: Math, baby!
# Now that we have the survey data, how can we get meaningful insight from it? If we think about the array of interest scores as a set of points that represent the persons overall interests as a **coordinate** then we can look for the closest coordinate and assume that that is representitive of the person with the closest interests!
#
# So how do we find the closest person?
#
#
# we establishes that we should represent each person as a coordinate of their interests and from there
#
# we can look at the distance between all the other coordinates on the and pick the one with that is closest
#
# There are many metrics to measure distance but we will use the straight line distance from each point as ours. This is called Euclidean Distance and can be written out as:
#
# $\sqrt{\sum_{i=1}^n (x_i-y_i)^2}$
#
#
# *Feel free to try other distance or similiarity metrics*
#
# Now that we have a way to measure the distance between each persons interest coordinate, we can find the closest person to each person by making a list of the distances of a person to every other person in the list. In this case we can record the distance from a mentor to every other student and then sort them in acending order. Since we have a sorted list of the closest students, lets call the neighbors, the closest student would be the first person in the list, the second closest would be the 2nd person on the list, and so on. In general we can find any number of the nearest neighbors this way!
#
# In this case we only look for the closest student on the list but you can play around with the ammount of nearest neighbors you look for.
#
#
# Google these for more info:
# Euclidean Distance
#
# K-Nearest-Neighbors

# %%
def distance(pers1, pers2):
  squared_difference = 0
  for i in range(len(pers1)):
    squared_difference += (pers1[i] - pers2[i]) ** 2
  final_distance = squared_difference ** 0.5
  return final_distance

def knn(unknown, dataset, k=1):
  distances = []
  #Looping through all points in the dataset
  for name in dataset:
    scores = dataset[name]
    distance_to_point = distance(scores, unknown)
    #Adding the distance and point associated with that distance
    distances.append([distance_to_point, name])
  distances.sort()
  #Taking only the k closest points
  neighbors = distances[0:k]
  return neighbors[0]
  
knn([5,5,5,5,5], mentor_dataset)
# Out:
# [1.4142135623730951, 'David Womack']

# %% [markdown]
# # Matching process

# %% [markdown]
# The matching process is quite simple. We go through the dataset of mentors and match every mentor to the student closest to them. We check if any student doesnt have a mentor and then we match the mentors again until all the students have been matched!
#
#
# Steps:
#
# make an empty dictionary recording mentors and their mentee(s);
#
# While there are students that are not matched to a mentor:
#   For each mentor:
#     match them to the student that is the most similiar

# %%
matched_list = {}
for i in mentor_dataset:
    matched_list[i] = []
while(len(student_dataset) != 0):
    for i in mentor_dataset:
        if len(student_dataset) != 0:
            matched_student = knn(mentor_dataset[i], student_dataset)[1]
            matched_list[i].append(matched_student)
            del student_dataset[matched_student]
        else:
            matched_list[i].append('')

print(matched_list)
# Out:
# {'Sarah Shafer': ['Shirley Lawrence', 'Christina Piere', 'Jon Wojcik'], 'Diane Mccants': ['Laurence France', 'Joseph Brockhaus', 'Stephen Morales'], 'Connie Watson': ['Lisa Lang', 'Elizabeth Brayman', ''], 'Robert Lorenzen': ['Michael Plowman', 'Cindy Ness', ''], 'George White': ['Don Wilburn', 'Ethel Howell', ''], 'Larry Lacroix': ['Dedra Blais', 'Luvenia Silver', ''], 'Edward Cramer': ['Annmarie Reasoner', 'Michael Dietz', ''], 'Neva Milburn': ['Sharon Castellanos', 'Otto Huerta', ''], 'Shiela Frank': ['Darlene Clifton', 'Sharon Boyd', ''], 'Shannon Troendle': ['Davis Finke', 'Denise Butler', ''], 'Greg Erdmann': ['Adrian Morris', 'Susan Stewart', ''], 'Mary Cormier': ['Joan Parks', 'Emil Morrison', ''], 'Reginald Spindler': ['Bradley Southard', 'James Cason', ''], 'Maria Overbaugh': ['Tyrone Davis', 'Ophelia Toney', ''], 'Carlos Stroud': ['Jonathan Gonzalez', 'Lidia Demery', ''], 'Eleanor Perryman': ['Patricia Luckman', 'Ophelia Kostura', ''], 'Bonnie Shute': ['Eric Williams', 'Andre Rivas', ''], 'Christopher Robinson': ['Gerald Stevenson', 'Linda Andreas', ''], 'Stanley Stanton': ['Edith Mendez', 'Terry Smith', ''], 'Lisa Phillips': ['Betty Bratton', 'Georgianna Jackson', ''], 'Lisa Tompkins': ['Anderson Sim', 'Glennis Engemann', ''], 'Eric Hutchison': ['Juliette Johnson', 'Robert Fenton', ''], 'Chester Vanconant': ['Camille Martino', 'Willie Harris', ''], 'Raymond Hruska': ['Jose Sardi', 'Don Patton', ''], 'William Hsu': ['Alberto Leverett', 'Paulette Olson', ''], 'Edward Chappell': ['Annette Hall', 'Josie Ruper', ''], 'Vanessa Holmes': ['Darlene Aguirre', 'Cecile Whiteis', ''], 'Jamila Sutton': ['Dorris Graves', 'Leticia Steel', ''], 'Jean Dirks': ['Lisa Barwick', 'Mina Deutsch', ''], 'Lolita Ruiz': ['Willie Thompson', 'Zachariah Gilmore', ''], 'John Hernandez': ['Gary Boehme', 'Nelly Humphrey', ''], 'Kurt Smith': ['Maggie Donaldson', 'Gerald Esparza', ''], 'Deborah Elliott': ['Harry Dalton', 'Doug Prince', ''], 'Ramona Sims': ['Alice Howell', 'Harry Carathers', ''], 'Sheri Oswald': ['Alfred Gillispie', 'Amanda Legore', ''], 'David Womack': ['Amanda Johnson', 'Frank Malone', ''], 'Ronnie Lawton': ['Melinda Foxworth', 'Arthur Kratzer', ''], 'Paul Lankford': ['John Edgerly', 'Concetta Messina', ''], 'Nicole Hamill': ['Shaun Looney', 'Timothy Beebee', ''], 'John Kenkel': ['Gary Quezada', 'Monte Dooley', ''], 'Tony Watkins': ['Jessie Clough', 'Kira Strom', ''], 'Daniel Garlington': ['Douglas Mohan', 'Julie Reed', ''], 'Mack Carter': ['Dustin Waiters', 'Lee Hedin', ''], 'Scott Vanschaick': ['Thomas Gunderson', 'Donna Reyes', ''], 'Jamie Yazzie': ['John Brown', 'Keri Goddard', ''], 'Catherine Lowe': ['Omar Koetje', 'Yanira Tyler', ''], 'Louie Niebaum': ['Kelly Fitzgerald', 'David Daniel', ''], 'Susan Weske': ['Brenda Sanchez', 'Henry Reichenbach', ''], 'George Davis': ['Byron Murphy', 'Colette Cowell', ''], 'Thomas Leake': ['Robert Lynch', 'Estella Harrell', ''], 'Harold Green': ['Andrew Zastrow', 'Joseph Rosa', ''], 'Nathan Yates': ['Antonia Burton', 'Dennis Guerrero', ''], 'Edward Clayton': ['Allen Hodge', 'Francisco Mcgowan', ''], 'John Lundy': ['Carma Williams', 'Raymond Legace', ''], 'Delia Turner': ['Lillian Gilbert', 'Marsha Spencer', ''], 'Jared Ortiz': ['Julia Wilson', 'Phyllis Casey', ''], 'Mathew Visitacion': ['John Schultheis', 'Linda Toles', ''], 'Benjamin Bryce': ['Tina Trickel', 'Sherry Vogus', ''], 'Jill Stromberg': ['Tammi Myhre', 'William Stroud', ''], 'Michael Hill': ['Elizabeth Cardoza', 'Darrell Rhames', ''], 'John Brandt': ['Kristy Francis', 'Jane Ramires', ''], 'Cherri Trombley': ['Jaime Bye', 'Edward Jensen', ''], 'Nikki Williams': ['Janice Saylor', 'William Highshaw', ''], 'Eric Sparks': ['Josephine Bixler', 'Mason Weitzel', ''], 'Joseph Horn': ['Judith Ruiz', 'Christie Herstad', ''], 'Roosevelt Frey': ['Linda Miller', 'Pilar Hall', ''], 'Reggie Bartlett': ['Christopher Fralick', 'Mildred Ballinger', ''], 'Michael Romano': ['Sabrina Gilbert', 'Warren Lauritsen', ''], 'George Krug': ['Marisela Crary', ' ...

# %%
df = pd.DataFrame(matched_list)
# writer = pd.ExcelWriter('output.xlsx',engine='xlsxwriter')
# df.to_html()
# writer.save()
df
# Out:
#      Aaron Gomes Aaron Saunders      Adam Butler   Aileen Newman  \
# 0   Neal Bratton    Mary Sexton  Thomas Mcdowell  James Benjamin
# 1  Gordon Stiner     Jerry Lira     Randy Gaddie   Maggie Wilson
# 2
#
#      Alice Gates    Alice Tanner     Alvin Buford   Alvin Carlyle  \
# 0     Ralph Hart    Barbara Rich   Eleanor Turner  Carmen Bentley
# 1  Tara Sullivan  Claudia Thomas  Salvador Espino   Monica Ronson
# 2
#
#       Alvina Plues  Amy Williams       ...         Tommy Harner  \
# 0  Donna Debartolo    Dennis Lum       ...           Luis Gould
# 1       Mary Klena  Glenn Pullen       ...         Kenneth Lane
# 2                                      ...
#
#     Tony Watkins  Trisha Salazar   Vanessa Holmes Wayne Turbacuski  \
# 0  Jessie Clough  John Mccasland  Darlene Aguirre     Patrick Odom
# 1     Kira Strom    Robert Tully   Cecile Whiteis    Jeffrey Dietz
# 2
#
#         William Hsu  William Metz  William Sands Willie Hollingsworth  \
# 0  Alberto Leverett   Eric Barnes  Esther Grotts       Joel Armstrong
# 1    Paulette Olson  Lorrie Amaya   Ruben Harris          Thomas Trim
# 2
#
#       Wilton Lewis
# 0  Frank Castaneda
# 1       Jose Otero
# 2
#
# [3 rows x 299 columns]

# %% [markdown]
# # How can you make this better?
#
# The mentorship problem is important to P-TECH and I am curious as to how you could make this better. I invite anyone interested in this problem to improve this work or try different aproaches!
#
# There is ample area for improvement in the mentor program and I am excited to see other approaches to this aswell.
#
# Feel free to play wit this notebook! Play with some of the distance or similiarity metrics to see if you can get better results.
